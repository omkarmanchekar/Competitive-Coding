# %%
# ########## U cannot iterate through tree node or find len(root) whcih is tree node so flop show cannot do with arrays




# root = [3,5,1,6,2,0,8,'null','null',7,4]
# target = 5
# k = 2



# def dfs(d,root,index):
#     N=len(root)
#     if(index*2+1 in range(N) and root[index*2+1] != 'null'):
#         d[root[index*2+1]] = (root[index],index)
#         dfs(d,root,index*2+1)
#     if(index*2+2 in range(N) and root[index*2+2] != 'null'):
#         d[root[index*2+2]] = (root[index],index)
#         dfs(d,root,index*2+2)

#     return d

# def sol(root,target,k):

#     d={}
#     queue=[]
#     visited=[]
#     dic=[]
#     result=[]
#     for index,value in enumerate(root):
#         dic.append(value)
#         if(value == target):
#             visited.append(value)
#             queue.append((value,index,0))


#     DFS=dfs(d,dic,0)


#     while(queue):
#         value,index,cost= queue.pop(0)
#         if(cost == k ):
#             result.append(value)
#         else:
#             for i in [(index*2+1),(index*2+2)]:
#                 if(i in range(len(dic)) and dic[i] not in visited and dic[i] != 'null'):
#                     queue.append((dic[i],i,cost+1))
#                     visited.append(value)
#             if(value in d and d[value][0] not in visited):
#                 queue.append((d[value][0],d[value][1],cost+1))
#                 visited.append(d[value][0])



#     return result





# sol(root,target,k)

# %% [markdown]
# <h2>incomplete</h2>

# %%
# root = [3,5,1,6,2,0,8,'null','null',7,4]
# target = 5
# k = 2


# def dfs(d,root):
#     if(root.left):
#         d[root.left.val] = root
#         dfs(d,root.left)
#     if(root.right):
#         d[root.right.val] = root
#         dfs(d,root.right)
    
#     return d

# def sol(root,target,k):
#     queue=[]
#     visited=[]
#     parent_nodes={}
#     result=[]
#     dfs(parent_nodes,root)

#     queue.append((target,0))
#     visited.append(target)

#     while(queue):
#         node,cost=queue.pop(0)
#         if(cost==k):
#             result.append(node)
#         else:
#             for i in [node.left,node.right]:
#                 if(i and i not in visited):
#                     visited.append(i)
#                     queue.append(i,cost+1)
#             if(node in parent_nodes and parent_nodes[i] not in visited):
#                 queue.append((parent_nodes[node],cost+1))
#                 visited.append(parent_nodes[node])
            
#     return result
